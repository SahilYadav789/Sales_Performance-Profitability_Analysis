# %% [markdown]
# ***Key Performance Indicators***

# %% [markdown]
# Total Revenue = 354200
#
# Total Profit = 88000
#
# Total Orders = 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***Trend Analysis by Month***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***Story of Data according to Insights***

# %% [markdown]
# * According to Insights of Data, the month of March is generating highest Revenue and the trend shows that revenue will increse in future.
# * Laptop is generating highest Revenue and Mobiles are sold most which increses the volume of sales.
# * Laptops are generating highest profit.
# * Electronics are most demanded by customers but, company can recommend customers to buy accessories.
# * Company should focus on Mobiles as they are most sold and company can sell keyboards with laptop at 55999 then keyboards sale can
#   also increase
